# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import glob
all_data=glob.glob("D:/ai and ds course/5H data cleaning scraping/data/*")

# %%
len(all_data)
# Out:
# 10

# %%
df_concate=pd.concat(map(pd.read_excel,all_data))

# %%
df_concate.head()
# Out:
#                  Address Bedrooms Bathrooms        Area Year Built  \
# 0    9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1       460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2  1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3    5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4  2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
#
#         Parking     Price     Location
# 0  2 Car Garage  $330,000  Albuquerque
# 1  2 Car Garage  $289,900  Albuquerque
# 2       No Info  $155,000  Albuquerque
# 3  2 Car Garage  $269,900  Albuquerque
# 4  2 Car Garage  $450,000  Albuquerque

# %%
df_concate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8755 entries, 0 to 859
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     8755 non-null   object
#  1   Bedrooms    8255 non-null   object
#  2   Bathrooms   8145 non-null   object
#  3   Area        8020 non-null   object
#  4   Year Built  8333 non-null   object
#  5   Parking     8263 non-null   object
#  6   Price       8752 non-null   object
#  7   Location    8755 non-null   object
# dtypes: object(8)
# memory usage: 615.6+ KB

# %%
df_concate.isnull().sum()
# Out:
# Address         0
# Bedrooms      500
# Bathrooms     610
# Area          735
# Year Built    422
# Parking       492
# Price           3
# Location        0
# dtype: int64

# %%
df_concate.to_csv('alldata.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-147a0d720f10> in <module>
# ----> 1 df_concate.to_csv('alldata.csv',index=False)
#
# NameError: name 'df_concate' is not defined

# %%
df=pd.read_csv('alldata.csv')

# %%
df
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 8750      1715 Euclid St NW   6 Beds       NaN         NaN       1906
# 8751           2015 Q St NW   6 Beds       NaN  5,285 sqft       1925
# 8752     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 8753   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 8754   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#                Parking       Price     Location
# 0         2 Car Garage    $330,000  Albuquerque
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8755 entries, 0 to 8754
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     8755 non-null   object
#  1   Bedrooms    8255 non-null   object
#  2   Bathrooms   8145 non-null   object
#  3   Area        8020 non-null   object
#  4   Year Built  8333 non-null   object
#  5   Parking     8263 non-null   object
#  6   Price       8752 non-null   object
#  7   Location    8755 non-null   object
# dtypes: object(8)
# memory usage: 547.3+ KB

# %%
df[df.isnull().any(axis=1)]
# Out:
#                       Address Bedrooms Bathrooms        Area Year Built  \
# 370             Pajarito Mesa      NaN       NaN         NaN        NaN
# 376     1033 Forrester Ave NW   Studio       NaN    600 sqft       1977
# 400     1920 Broadway Blvd SE   2 Beds    1 Bath         NaN       1962
# 402   1990 1/2 Cherokee Rd NW      NaN       NaN         NaN        NaN
# 404          1301 Iron Ave SW   2 Beds   2 Baths         NaN       1916
# ...                       ...      ...       ...         ...        ...
# 8693   235 Emerson St NW #101    1 Bed    1 Bath         NaN       1929
# 8712         2308 Tracy Pl NW   6 Beds   6 Baths         NaN       1919
# 8713        2017 Rear 2 St NE      NaN       NaN         NaN        NaN
# 8750        1715 Euclid St NW   6 Beds       NaN         NaN       1906
# 8751             2015 Q St NW   6 Beds       NaN  5,285 sqft       1925
#
#                Parking       Price     Location
# 370                NaN     $13,000  Albuquerque
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.histplot(df.isnull())
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8755 entries, 0 to 8754
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     8755 non-null   object
#  1   Bedrooms    8255 non-null   object
#  2   Bathrooms   8145 non-null   object
#  3   Area        8020 non-null   object
#  4   Year Built  8333 non-null   object
#  5   Parking     8263 non-null   object
#  6   Price       8752 non-null   object
#  7   Location    8755 non-null   object
# dtypes: object(8)
# memory usage: 547.3+ KB

# %%
df[df.isnull().any(axis=1)]
# Out:
#                       Address Bedrooms Bathrooms        Area Year Built  \
# 370             Pajarito Mesa      NaN       NaN         NaN        NaN
# 376     1033 Forrester Ave NW   Studio       NaN    600 sqft       1977
# 400     1920 Broadway Blvd SE   2 Beds    1 Bath         NaN       1962
# 402   1990 1/2 Cherokee Rd NW      NaN       NaN         NaN        NaN
# 404          1301 Iron Ave SW   2 Beds   2 Baths         NaN       1916
# ...                       ...      ...       ...         ...        ...
# 8693   235 Emerson St NW #101    1 Bed    1 Bath         NaN       1929
# 8712         2308 Tracy Pl NW   6 Beds   6 Baths         NaN       1919
# 8713        2017 Rear 2 St NE      NaN       NaN         NaN        NaN
# 8750        1715 Euclid St NW   6 Beds       NaN         NaN       1906
# 8751             2015 Q St NW   6 Beds       NaN  5,285 sqft       1925
#
#                Parking       Price     Location
# 370                NaN     $13,000  Albuquerque
# ...

# %%
df =df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7826 entries, 0 to 8754
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     7826 non-null   object
#  1   Bedrooms    7826 non-null   object
#  2   Bathrooms   7826 non-null   object
#  3   Area        7826 non-null   object
#  4   Year Built  7826 non-null   object
#  5   Parking     7826 non-null   object
#  6   Price       7826 non-null   object
#  7   Location    7826 non-null   object
# dtypes: object(8)
# memory usage: 550.3+ KB

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index                Address Bedrooms Bathrooms        Area Year Built  \
# 0         0    9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1         1       460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2         2  1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3         3    5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4         4  2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...     ...                    ...      ...       ...         ...        ...
# 7821   8748  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 7822   8749   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 7823   8752     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 7824   8753   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 7825   8754   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking       Price     Location
# ...

# %%
df
# Out:
#       index                Address Bedrooms Bathrooms        Area Year Built  \
# 0         0    9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1         1       460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2         2  1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3         3    5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4         4  2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...     ...                    ...      ...       ...         ...        ...
# 7821   8748  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 7822   8749   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 7823   8752     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 7824   8753   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 7825   8754   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking       Price     Location
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7826 entries, 0 to 7825
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       7826 non-null   int64
#  1   Address     7826 non-null   object
#  2   Bedrooms    7826 non-null   object
#  3   Bathrooms   7826 non-null   object
#  4   Area        7826 non-null   object
#  5   Year Built  7826 non-null   object
#  6   Parking     7826 non-null   object
#  7   Price       7826 non-null   object
#  8   Location    7826 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 550.4+ KB

# %%
df.drop(columns=['index'],inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 7821  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 7822   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 7823     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 7824   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 7825   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking       Price     Location
# 0     2 Car Garage    $330,000  Albuquerque
# ...

# %%
df[df.duplicated()]
# Out:
#                           Address Bedrooms Bathrooms        Area Year Built  \
# 80            1829 Illinois St NE   5 Beds   2 Baths  1,797 sqft       1954
# 81          9109 Crestwood Ave NE   3 Beds   3 Baths  2,183 sqft       1963
# 82               3401 Cagua Dr NE   3 Beds   2 Baths  1,831 sqft       1955
# 83               1325 Hertz Dr SE   3 Beds   3 Baths  3,335 sqft       1975
# 84             1020 Indiana St SE   4 Beds   2 Baths  1,950 sqft       1953
# ...                           ...      ...       ...         ...        ...
# 7748         525 Water St SW #420   3 Beds   3 Baths  1,724 sqft       2016
# 7749         1032 Lamont St NW #A   3 Beds   3 Baths  1,464 sqft       1907
# 7750          2403 Savannah St SE   3 Beds   2 Baths  1,405 sqft       1950
# 7751          7508 Eastern Ave NW   3 Beds   3 Baths  1,088 sqft       1948
# 7798  2660 Connecticut Ave NW #7C   3 Beds   4 Baths  4,648 sqft       1928
#
#                Parking       Price     Location
# ...

# %%
df.drop_duplicates(inplace=True)
# Out:
# <ipython-input-20-16cdb8520be8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 7821  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 7822   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 7823     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 7824   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 7825   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking       Price     Location
# 0     2 Car Garage    $330,000  Albuquerque
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 7821  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 7822   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 7823     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 7824   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 7825   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking       Price     Location
# 0     2 Car Garage    $330,000  Albuquerque
# ...

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking       Price     Location
# 0     2 Car Garage    $330,000  Albuquerque
# ...

# %%
df=df.rename(columns={'Price':'Price$'})

# %%
df
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking      Price$     Location
# 0     2 Car Garage    $330,000  Albuquerque
# ...

# %%
def removedoll(data):
    data=data.replace('$','')
    return data

# %%
df['Price$']=df['Price$'].apply(removedoll)

# %%
df
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking     Price$     Location
# 0     2 Car Garage    330,000  Albuquerque
# ...

# %%
def removecom(data):
    data=data.replace(',','')
    return data

# %%
df['Price$']=df['Price$'].apply(removecom)

# %%
df
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking   Price$     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# ...

# %%
df=df.rename(columns={'Area':'Area(sqft)'})

# %%
df
# Out:
#                     Address Bedrooms Bathrooms  Area(sqft) Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking   Price$     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# ...

# %%
df['Area(sqft)']=df['Area(sqft)'].str.strip('sqft')

# %%
df
# Out:
#                     Address Bedrooms Bathrooms Area(sqft) Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths     2,000        1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths     2,212        2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath       815        1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths     1,600        1977
# 4     2804 Charleston St NE   4 Beds   3 Baths     2,445        1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths     1,200        1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath       835        2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath       743        1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths     2,078        1985
# 6245   2125 14th St NW #309   Studio    1 Bath       538        2007
#
#            Parking   Price$     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# ...

# %%
df['Area(sqft)']=df['Area(sqft)'].str.replace(',','')

# %%
df
# Out:
#                     Address Bedrooms Bathrooms Area(sqft) Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths      2000        1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths      2212        2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath       815        1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths      1600        1977
# 4     2804 Charleston St NE   4 Beds   3 Baths      2445        1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths      1200        1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath       835        2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath       743        1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths      2078        1985
# 6245   2125 14th St NW #309   Studio    1 Bath       538        2007
#
#            Parking   Price$     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# ...

# %%
df['Bedrooms']=df.Bedrooms.str.strip('Beds')

# %%
df
# Out:
#                     Address Bedrooms Bathrooms Area(sqft) Year Built  \
# 0       9400 La Playa St NE       4    3 Baths      2000        1975
# 1          460 Wesley Ct SW       4    3 Baths      2212        2003
# 2     1307 Bernardino Rd NW       2     1 Bath       815        1948
# 3       5215 Cimarron Rd NW       3    2 Baths      1600        1977
# 4     2804 Charleston St NE       4    3 Baths      2445        1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE       3    4 Baths      1200        1933
# 6242   1111 25th St NW #304       2     1 Bath       835        2005
# 6243     922 24th St NW #5B       1     1 Bath       743        1962
# 6244   1099 22nd St NW #401       3    3 Baths      2078        1985
# 6245   2125 14th St NW #309   Studio    1 Bath       538        2007
#
#            Parking   Price$     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# ...

# %%
df[df['Bedrooms']=='Studio']
# Out:
#                                          Address Bedrooms Bathrooms  \
# 125                            401 High St SE #6   Studio    1 Bath
# 207                      301 Central Ave NE #306   Studio    1 Bath
# 331                      401 Central Ave NE #305   Studio   2 Baths
# 1142  3501-3501 Brookside Parkway South Dr #3509   Studio    1 Bath
# 2538                         555 NE 15th St #520   Studio    1 Bath
# ...                                          ...      ...       ...
# 6167                           2500 Q St NW #337   Studio    1 Bath
# 6180                        950 25th St NW #N111   Studio    1 Bath
# 6216                           560 N St SW #N507   Studio    1 Bath
# 6231                        1701 16th St NW #318   Studio    1 Bath
# 6245                        2125 14th St NW #309   Studio    1 Bath
#
#      Area(sqft) Year Built       Parking  Price$      Location
# 125        788        2005       No Info  143500   Albuquerque
# ...

# %%
df.Bedrooms.unique()
# Out:
# array(['4 ', '2 ', '3 ', '5 ', '1 ', 'Studio', '7 ', '6 ', '8 ', '10 ',
#        '9 ', '13 ', '11 ', '12 ', '84 ', '14 ', '24 '], dtype=object)

# %%
df.Bedrooms.value_counts()
# Out:
# 3         2122
# 2         1376
# 4         1312
# 5          525
# 1          473
# 6          214
# Studio      80
# 7           75
# 8           37
# 9           17
# 11           5
# 12           3
# 10           3
# 24           1
# 14           1
# 84           1
# 13           1
# Name: Bedrooms, dtype: int64

# %%
df[df['Bedrooms']=='Studio']
# Out:
#                                          Address Bedrooms Bathrooms  \
# 125                            401 High St SE #6   Studio    1 Bath
# 207                      301 Central Ave NE #306   Studio    1 Bath
# 331                      401 Central Ave NE #305   Studio   2 Baths
# 1142  3501-3501 Brookside Parkway South Dr #3509   Studio    1 Bath
# 2538                         555 NE 15th St #520   Studio    1 Bath
# ...                                          ...      ...       ...
# 6167                           2500 Q St NW #337   Studio    1 Bath
# 6180                        950 25th St NW #N111   Studio    1 Bath
# 6216                           560 N St SW #N507   Studio    1 Bath
# 6231                        1701 16th St NW #318   Studio    1 Bath
# 6245                        2125 14th St NW #309   Studio    1 Bath
#
#      Area(sqft) Year Built       Parking  Price$      Location
# 125        788        2005       No Info  143500   Albuquerque
# ...

# %%
df['Bedrooms']=df['Bedrooms'].replace('Studio',1)

# %%
df
# Out:
#                     Address Bedrooms Bathrooms Area(sqft) Year Built  \
# 0       9400 La Playa St NE       4    3 Baths      2000        1975
# 1          460 Wesley Ct SW       4    3 Baths      2212        2003
# 2     1307 Bernardino Rd NW       2     1 Bath       815        1948
# 3       5215 Cimarron Rd NW       3    2 Baths      1600        1977
# 4     2804 Charleston St NE       4    3 Baths      2445        1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE       3    4 Baths      1200        1933
# 6242   1111 25th St NW #304       2     1 Bath       835        2005
# 6243     922 24th St NW #5B       1     1 Bath       743        1962
# 6244   1099 22nd St NW #401       3    3 Baths      2078        1985
# 6245   2125 14th St NW #309        1    1 Bath       538        2007
#
#            Parking   Price$     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# ...

# %%
df.Bedrooms.unique()
# Out:
# array(['4 ', '2 ', '3 ', '5 ', '1 ', 1, '7 ', '6 ', '8 ', '10 ', '9 ',
#        '13 ', '11 ', '12 ', '84 ', '14 ', '24 '], dtype=object)

# %%
df['Bathrooms']=df.Bathrooms.str.strip('Baths')

# %%
df
# Out:
#                     Address Bedrooms Bathrooms Area(sqft) Year Built  \
# 0       9400 La Playa St NE       4         3       2000        1975
# 1          460 Wesley Ct SW       4         3       2212        2003
# 2     1307 Bernardino Rd NW       2         1        815        1948
# 3       5215 Cimarron Rd NW       3         2       1600        1977
# 4     2804 Charleston St NE       4         3       2445        1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE       3         4       1200        1933
# 6242   1111 25th St NW #304       2         1        835        2005
# 6243     922 24th St NW #5B       1         1        743        1962
# 6244   1099 22nd St NW #401       3         3       2078        1985
# 6245   2125 14th St NW #309        1        1        538        2007
#
#            Parking   Price$     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# ...

# %%
df.Parking.unique()
# Out:
# array(['2 Car Garage', 'No Info', 'Garage', '1 Car Garage',
#        '3 Car Garage', '1 Carport Spaces', '2 Carport Spaces',
#        '3 Carport Spaces', '4 Car Garage', '2 Parking Spaces',
#        '5 Parking Spaces', '4 Parking Spaces', '3.5 Car Garage',
#        '8 Parking Spaces', '10 Car Garage', '6 Car Garage',
#        '1 Parking Spaces', '5 Car Garage', '11 Car Garage', 'Carport',
#        '8 Car Garage', '6 Parking Spaces', 'Attached Garage',
#        'Open Parking', '4 Carport Spaces', '7 Car Garage',
#        '5 Carport Spaces', 'None', '9 Car Garage', '0 Carport Spaces',
#        '2 Open Spaces', '4 Open Spaces', '1 Open Spaces', '3 Open Spaces',
#        '5 Open Spaces', '3 Parking Spaces', '20 Car Garage',
#        '0 Open Spaces', '9 Parking Spaces', '54 Carport Spaces',
#        '206 Car Garage', '59 Car Garage'], dtype=object)

# %%
df.Parking.value_counts()
# Out:
# Garage               1623
# No Info              1136
# 2 Car Garage         1020
# Open Parking          805
# 1 Car Garage          487
# 3 Car Garage          333
# Attached Garage       158
# None                  142
# 1 Parking Spaces      134
# 4 Car Garage           80
# 1 Carport Spaces       69
# 1 Open Spaces          39
# 2 Open Spaces          37
# 2 Parking Spaces       35
# 2 Carport Spaces       28
# Carport                23
# 0 Open Spaces          17
# 6 Car Garage           14
# 5 Car Garage           11
# 4 Parking Spaces        8
# 3 Open Spaces           6
# 5 Open Spaces           5
# 4 Open Spaces           5
# 3 Parking Spaces        4
# 8 Car Garage            4
# 8 Parking Spaces        3
# 3 Carport Spaces        3
# 9 Car Garage            2
# 6 Parking Spaces        2
# 11 Car Garage           1
# 7 Car Garage            1
# 3.5 Car Garage          1
# 59 Car Garage           1
# 5 Carport Spaces        1
# 10 Car Garage           1
# ...

# %%
df['Parking']=df.Parking.apply(lambda x:'yes' if 'Garage' in x or 'Carport' in x or 'Car' in x or 'Open' in x
                              else 'no')

# %%
df.Parking.value_counts()
# Out:
# yes    4780
# no     1466
# Name: Parking, dtype: int64

# %%
df
# Out:
#                     Address Bedrooms Bathrooms Area(sqft) Year Built Parking  \
# 0       9400 La Playa St NE       4         3       2000        1975     yes
# 1          460 Wesley Ct SW       4         3       2212        2003     yes
# 2     1307 Bernardino Rd NW       2         1        815        1948      no
# 3       5215 Cimarron Rd NW       3         2       1600        1977     yes
# 4     2804 Charleston St NE       4         3       2445        1963     yes
# ...                     ...      ...       ...        ...        ...     ...
# 6241  2232 Mount View Pl SE       3         4       1200        1933     yes
# 6242   1111 25th St NW #304       2         1        835        2005     yes
# 6243     922 24th St NW #5B       1         1        743        1962     yes
# 6244   1099 22nd St NW #401       3         3       2078        1985     yes
# 6245   2125 14th St NW #309        1        1        538        2007      no
#
#        Price$     Location
# ...

# %%
df.dtypes
# Out:
# Address       object
# Bedrooms      object
# Bathrooms     object
# Area(sqft)    object
# Year Built    object
# Parking       object
# Price$        object
# Location      object
# dtype: object

# %%
df['Bedrooms']=df['Bedrooms'].astype(int)

# %%
df.dtypes
# Out:
# Address       object
# Bedrooms       int32
# Bathrooms     object
# Area(sqft)    object
# Year Built    object
# Parking       object
# Price$        object
# Location      object
# dtype: object

# %%
df['Bathrooms']=df['Bathrooms'].astype(int)

# %%
df.dtypes
# Out:
# Address       object
# Bedrooms       int32
# Bathrooms      int32
# Area(sqft)    object
# Year Built    object
# Parking       object
# Price$        object
# Location      object
# dtype: object

# %%
df['Area(sqft)']=df['Area(sqft)'].astype(int)
df.dtypes
# Out:
# Address       object
# Bedrooms       int32
# Bathrooms      int32
# Area(sqft)     int32
# Year Built    object
# Parking       object
# Price$        object
# Location      object
# dtype: object

# %%
df['Year Built']=df['Year Built'].astype(int)
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-0d2a1be68f17> in <module>
# ----> 1 df['Year Built']=df['Year Built'].astype(int)
#       2 df.dtypes
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
# ...

# %%
df['Year Built'].value_counts()
# Out:
# 2021.0    306
# 2021      175
# 1925      156
# 1900      153
# 1920      144
#          ...
# 1902.0      1
# 1874        1
# 1865        1
# 1901.0      1
# 1865.0      1
# Name: Year Built, Length: 288, dtype: int64

# %%
df['Year Built'].describe()
# Out:
# count       6246
# unique       288
# top       2021.0
# freq         306
# Name: Year Built, dtype: object

# %%
df['Year Built'].min()
# Out:
# '1752'

# %%
df['Year Built'].max()
# Out:
# 'No Info'

# %%
df[df['Year Built']=='No Info']
# Out:
#                           Address  Bedrooms  Bathrooms  Area(sqft) Year Built  \
# 10    2304 General Marshall St NE         3          2        1877    No Info
# 24         6408 Los Pueblos Pl NW         3          3        1930    No Info
# 25        2128 Altura Verde Ln NE         3          3        2060    No Info
# 33               9720 Stone St NW         3          3        2378    No Info
# 54        1705 Los Jardines Pl NW         2          2         864    No Info
# ...                           ...       ...        ...         ...        ...
# 5517       875 California St #402         2          2        1444    No Info
# 5532           960 Market St #304         1          1         344    No Info
# 5534           821 Folsom St #310         1          1         717    No Info
# 5559          72 Townsend St #707         1          2         851    No Info
# 5560          1 Hawthorne St #23A         2          2        1558    No Info
#
# ...

# %%
df.dtypes
# Out:
# Address       object
# Bedrooms       int32
# Bathrooms      int32
# Area(sqft)     int32
# Year Built    object
# Parking       object
# Price$        object
# Location      object
# dtype: object

# %%
df['Year Built']=df['Year Built'].replace('No Info','0')

# %%
df['Year Built'].unique()
# Out:
# array(['1975', '2003', '1948', '1977', '1963', '1999', '1987', '2005',
#        '1973', '1949', '0', '1998', '1958', '1960', '1951', '1961',
#        '1964', '1962', '1979', '1957', '1955', '1971', '1954', '1950',
#        '2000', '2001', '1926', '1983', '1988', '1952', '1978', '1986',
#        '1989', '2006', '2002', '2007', '2004', '1972', '1906', '1953',
#        '2015', '1956', '1946', '1920', '1940', '1992', '2013', '1976',
#        '1959', '1941', '2019', '1985', '1966', '1991', '1974', '1984',
#        '1947', '2021', '1982', '1967', '1969', '2012', '1945', '2017',
#        '2014', '2010', '1997', '1968', '1914', '1938', '1965', '1993',
#        '1970', '1995', '1930', '1921', '1994', '2008', '1936', '1981',
#        '2018', '1980', '2020', '1905', '1937', '2011', '2016', '1996',
#        '2005.0', '2000.0', '2021.0', '1986.0', '1994.0', '2001.0',
#        '1958.0', '1985.0', '2010.0', '1968.0', '1974.0', '1923.0',
# ...

# %%
df['Year Built']=df['Year Built'].str.strip('.0')

# %%
df.dtypes
# Out:
# Address       object
# Bedrooms       int32
# Bathrooms      int32
# Area(sqft)     int32
# Year Built    object
# Parking       object
# Price$        object
# Location      object
# dtype: object

# %%
df['Year Built'].unique()
# Out:
# array(['1975', '2003', '1948', '1977', '1963', '1999', '1987', '2005',
#        '1973', '1949', '', '1998', '1958', '196', '1951', '1961', '1964',
#        '1962', '1979', '1957', '1955', '1971', '1954', '195', '2', '2001',
#        '1926', '1983', '1988', '1952', '1978', '1986', '1989', '2006',
#        '2002', '2007', '2004', '1972', '1906', '1953', '2015', '1956',
#        '1946', '192', '194', '1992', '2013', '1976', '1959', '1941',
#        '2019', '1985', '1966', '1991', '1974', '1984', '1947', '2021',
#        '1982', '1967', '1969', '2012', '1945', '2017', '2014', '201',
#        '1997', '1968', '1914', '1938', '1965', '1993', '197', '1995',
#        '193', '1921', '1994', '2008', '1936', '1981', '2018', '198',
#        '202', '1905', '1937', '2011', '2016', '1996', '1923', '1909',
#        '191', '1901', '1908', '1895', '1922', '199', '1918', '1899', '19',
#        '1898', '1902', '1925', '2009', '1927', '1919', '1893', '1894',
# ...

# %%
df
# Out:
#                     Address  Bedrooms  Bathrooms  Area(sqft) Year Built  \
# 0       9400 La Playa St NE         4          3        2000       1975
# 1          460 Wesley Ct SW         4          3        2212       2003
# 2     1307 Bernardino Rd NW         2          1         815       1948
# 3       5215 Cimarron Rd NW         3          2        1600       1977
# 4     2804 Charleston St NE         4          3        2445       1963
# ...                     ...       ...        ...         ...        ...
# 6241  2232 Mount View Pl SE         3          4        1200       1933
# 6242   1111 25th St NW #304         2          1         835       2005
# 6243     922 24th St NW #5B         1          1         743       1962
# 6244   1099 22nd St NW #401         3          3        2078       1985
# 6245   2125 14th St NW #309         1          1         538       2007
#
#      Parking   Price$     Location
# 0        yes   330000  Albuquerque
# ...

# %%
df['Price$']=df['Price$'].astype(int)
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-7a073f287cca> in <module>
# ----> 1 df['Price$']=df['Price$'].astype(int)
#       2 df.dtypes
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
# ...

# %%
df['Price$'].unique()
# Out:
# array(['330000', '289900', '155000', ..., '212000', '899999', '319500'],
#       dtype=object)

# %%
df['Price$']=df['Price$'].str.replace('+','')
# Out:
# <ipython-input-110-d7afd7859afd>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Price$']=df['Price$'].str.replace('+','')

# %%
df['Price$']=df['Price$'].astype(int)
df.dtypes
# Out:
# Address       object
# Bedrooms       int32
# Bathrooms      int32
# Area(sqft)     int32
# Year Built    object
# Parking       object
# Price$         int32
# Location      object
# dtype: object

# %%
df['Price/sqft']=df['Price$']/df['Area(sqft)']

# %%
df
# Out:
#                     Address  Bedrooms  Bathrooms  Area(sqft) Year Built  \
# 0       9400 La Playa St NE         4          3        2000       1975
# 1          460 Wesley Ct SW         4          3        2212       2003
# 2     1307 Bernardino Rd NW         2          1         815       1948
# 3       5215 Cimarron Rd NW         3          2        1600       1977
# 4     2804 Charleston St NE         4          3        2445       1963
# ...                     ...       ...        ...         ...        ...
# 6241  2232 Mount View Pl SE         3          4        1200       1933
# 6242   1111 25th St NW #304         2          1         835       2005
# 6243     922 24th St NW #5B         1          1         743       1962
# 6244   1099 22nd St NW #401         3          3        2078       1985
# 6245   2125 14th St NW #309         1          1         538       2007
#
#      Parking   Price$     Location  Price/sqft
# 0        yes   330000  Albuquerque  165.000000
# ...

# %%
df['Price/sqft']=df['Price/sqft'].round(2)

# %%
df
# Out:
#                     Address  Bedrooms  Bathrooms  Area(sqft) Year Built  \
# 0       9400 La Playa St NE         4          3        2000       1975
# 1          460 Wesley Ct SW         4          3        2212       2003
# 2     1307 Bernardino Rd NW         2          1         815       1948
# 3       5215 Cimarron Rd NW         3          2        1600       1977
# 4     2804 Charleston St NE         4          3        2445       1963
# ...                     ...       ...        ...         ...        ...
# 6241  2232 Mount View Pl SE         3          4        1200       1933
# 6242   1111 25th St NW #304         2          1         835       2005
# 6243     922 24th St NW #5B         1          1         743       1962
# 6244   1099 22nd St NW #401         3          3        2078       1985
# 6245   2125 14th St NW #309         1          1         538       2007
#
#      Parking   Price$     Location  Price/sqft
# 0        yes   330000  Albuquerque      165.00
# ...

# %%
df['Price/sqft'].describe()
# Out:
# count      6246.000000
# mean        616.918277
# std        7205.666641
# min           0.440000
# 25%         189.710000
# 50%         311.160000
# 75%         596.375000
# max      560000.000000
# Name: Price/sqft, dtype: float64

# %%
df[df['Price/sqft']==560000.000000]
# Out:
#              Address  Bedrooms  Bathrooms  Area(sqft) Year Built Parking  \
# 3564  3069 Heath Ave         3          2           1       1899      no
#
#       Price$  Location  Price/sqft
# 3564  560000  New York    560000.0

# %%
df=df.drop(3564)

# %%
df
# Out:
#                     Address  Bedrooms  Bathrooms  Area(sqft) Year Built  \
# 0       9400 La Playa St NE         4          3        2000       1975
# 1          460 Wesley Ct SW         4          3        2212       2003
# 2     1307 Bernardino Rd NW         2          1         815       1948
# 3       5215 Cimarron Rd NW         3          2        1600       1977
# 4     2804 Charleston St NE         4          3        2445       1963
# ...                     ...       ...        ...         ...        ...
# 6241  2232 Mount View Pl SE         3          4        1200       1933
# 6242   1111 25th St NW #304         2          1         835       2005
# 6243     922 24th St NW #5B         1          1         743       1962
# 6244   1099 22nd St NW #401         3          3        2078       1985
# 6245   2125 14th St NW #309         1          1         538       2007
#
#      Parking   Price$     Location  Price/sqft
# 0        yes   330000  Albuquerque      165.00
# ...

# %%
df.describe()
# Out:
#           Bedrooms    Bathrooms     Area(sqft)        Price$    Price/sqft
# count  6245.000000  6245.000000    6245.000000  6.245000e+03   6245.000000
# mean      3.211369     2.749720    2414.866934  1.435638e+06    527.345326
# std       1.758889     1.597855    7338.708926  4.925839e+06   1344.732083
# min       1.000000     1.000000      12.000000  1.895000e+03      0.440000
# 25%       2.000000     2.000000    1162.000000  3.239000e+05    189.710000
# 50%       3.000000     2.000000    1702.000000  5.099000e+05    311.150000
# 75%       4.000000     3.000000    2604.000000  9.250000e+05    596.330000
# max      84.000000    17.000000  430000.000000  1.690000e+08  70833.330000

# %%
df.to_excel('cleaned_data.xlsx')
